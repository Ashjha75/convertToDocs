# %% [markdown]
# # Using Google Colab / Jupyter Notebooks in VS Code
#
# You have successfully installed the necessary extensions!
#
# ## How to use this Notebook
# 1. **Select a Kernel**: Look at the top right of the editor. It might say "Select Kernel". Click it and choose "Python Environments" -> select your installed Python version.
# 2. **Run Code**: Click the "Play" button next to the code cell below, or press `Shift + Enter`.
#
# ## Is this Google Colab?
# This is a **Jupyter Notebook** (`.ipynb`). It works exactly like Google Colab, but it runs on your computer by default.
#
# ### Connecting to Google Colab (Cloud)
# If you specifically want to connect to a Google Colab runtime (e.g., to use their GPUs):
# 1. Open the Command Palette (`Ctrl+Shift+P`).
# 2. Type "Google Colab: Connect to Runtime" (requires the Google Colab extension).
# 3. Follow the sign-in instructions.
#
# For now, try running the code below to test your local setup!

# %%
# This is a code cell. 
# You can run Python code here just like in Colab.

print("Hello! Your VS Code Jupyter environment is working.")

# If you have libraries installed, you can import them:
import sys
print(f"Running on Python version: {sys.version}")
# Out:
# Hello! Your VS Code Jupyter environment is working.
# Running on Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
